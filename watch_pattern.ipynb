# %%
import os
import glob
import datetime
import numpy as np
import matplotlib.pyplot as plt

# %%
files = sorted(glob.glob('*1112*.csv'))

# %%
files
# Out:
# ['1112+50_1.2288.csv',
#  '1112+50_2.4576.csv',
#  '1112+50_3.8912.csv',
#  'new_sup1112+50_1.2288.csv',
#  'sup_AP_1112+50.csv']

# %%
i = 4
name_pul = files[i]
files[i]
# Out:
# 'sup_AP_1112+50.csv'

# %%
test_rear = np.loadtxt(name_pul, skiprows=4)

# %%
plt.close()
plt.plot(test_rear)
plt.xlabel('Number of point, ' + name_pul[-10:-4])
plt.ylabel('Intensity, arbitrary units')
#plt.savefig('pattern.png', format='png')
plt.axhline(0)
plt.show()
print(len(test_rear))
# Out:
# 88

# %%
name_pul = files[1]
test_rear = np.loadtxt(name_pul, skiprows=4) 
plt.close()
plt.plot(test_rear)
plt.xlabel('Number of point, ' + name_pul[-10:-4])
plt.ylabel('Intensity, arbitrary units')
#plt.savefig('pattern.png', format='png')
plt.axhline(0)
plt.show()
print(len(test_rear))
# Out:
# 300

# %%
name_pul = files[2]
test_rear = np.loadtxt(name_pul, skiprows=4) 
plt.close()
plt.plot(test_rear)
plt.xlabel('Number of point, ' + name_pul[-10:-4])
plt.ylabel('Intensity, arbitrary units')
#plt.savefig('pattern.png', format='png')
plt.axhline(0)
plt.show()
print(len(test_rear))
# Out:
# 40

# %%
name_pul = files[3]
test_rear = np.loadtxt(name_pul, skiprows=4) 
plt.close()
plt.plot(test_rear)
plt.xlabel('Number of point, ' + name_pul[-10:-4])
plt.ylabel('Intensity, arbitrary units')
#plt.savefig('pattern.png', format='png')
plt.axhline(0)
plt.show()
print(len(test_rear))
# Out:
# 30

# %%
zero_pat = [x for x in test_rear if x > 0]

# %%
plt.close()
plt.plot(zero_pat)
plt.xlabel('Number of point, ' + name_pul[-10:-4])
plt.ylabel('Intensity, arbitrary units')
#plt.savefig('pattern.png', format='png')
#plt.axhline(0)
plt.show()
print(len(test_rear))
# Out:
# 167

# %%
x = range(len(test_rear))
y1 = test_rear[::-1]
y2 = -1*test_rear[::-1]

# %%
plt.close()
plt.style.use('dark_background')
fig, ax1 = plt.subplots(1, 1, sharex=True)
plt.plot(y1, x)
plt.plot(y2, x)
#ax1.fill_between(x, y2, y1, facecolor='green', interpolate=False)
plt.show()

# %%
plt.close()
plt.plot(y1, x)
plt.plot(y2, x)
#ax1.fill_between(x, y2, y1, facecolor='green', interpolate=False)
plt.savefig('butterfly_' + name_pul[:-3] + '.png', format='png')
