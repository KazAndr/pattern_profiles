# %%
import os
import glob
import datetime
import numpy as np
import matplotlib.pyplot as plt

# %%
files = sorted(glob.glob('0943*.csv'))

# %%
files
# Out:
# ['0943+10_0.8192.csv',
#  '0943+10_0.8192_cut.csv',
#  '0943+10_0.8192_cut_slm.csv',
#  '0943+10_0.8192_peak.csv',
#  '0943+10_0.8192_slm.csv',
#  '0943+10_1.024.csv',
#  '0943+10_1.024_cut.csv',
#  '0943+10_1.024_cut_slm.csv',
#  '0943+10_1.024_peak.csv',
#  '0943+10_1.024_slm.csv',
#  '0943+10_2.4576.csv',
#  '0943+10_2.8672.csv',
#  '0943+10_2.8672_anomal.csv',
#  '0943+10_2.8672_cut.csv',
#  '0943+10_2.8672_cut_slm.csv',
#  '0943+10_2.8672_peak.csv',
#  '0943+10_2.8672_slm.csv',
#  '0943+10_2.8672peak.csv']

# %%
i = 12
name_pul = files[i]
files[i]
# Out:
# '0943+10_2.8672_anomal.csv'

# %%
test_rear = np.loadtxt(name_pul, skiprows=4)

# %%
plt.close()
plt.plot(test_rear)
plt.xlabel('Number of point, ' + name_pul[-10:-4])
plt.ylabel('Intensity, arbitrary units')
#plt.savefig('pattern.png', format='png')
plt.axhline(0)
plt.show()
print(len(test_rear))
# Out:
# 64

# %%
name_pul = files[1]
test_rear = np.loadtxt(name_pul, skiprows=4) 
plt.close()
plt.plot(test_rear)
plt.xlabel('Number of point, ' + name_pul[-10:-4])
plt.ylabel('Intensity, arbitrary units')
#plt.savefig('pattern.png', format='png')
plt.axhline(0)
plt.show()
print(len(test_rear))
# Out:
# 300

# %%
name_pul = files[2]
test_rear = np.loadtxt(name_pul, skiprows=4) 
plt.close()
plt.plot(test_rear)
plt.xlabel('Number of point, ' + name_pul[-10:-4])
plt.ylabel('Intensity, arbitrary units')
#plt.savefig('pattern.png', format='png')
plt.axhline(0)
plt.show()
print(len(test_rear))
# Out:
# 40

# %%
name_pul = files[3]
test_rear = np.loadtxt(name_pul, skiprows=4) 
plt.close()
plt.plot(test_rear)
plt.xlabel('Number of point, ' + name_pul[-10:-4])
plt.ylabel('Intensity, arbitrary units')
#plt.savefig('pattern.png', format='png')
plt.axhline(0)
plt.show()
print(len(test_rear))
# Out:
# 30

# %%
zero_pat = [x for x in test_rear if x > 0]

# %%
plt.close()
plt.plot(zero_pat)
plt.xlabel('Number of point, ' + name_pul[-10:-4])
plt.ylabel('Intensity, arbitrary units')
#plt.savefig('pattern.png', format='png')
#plt.axhline(0)
plt.show()
print(len(test_rear))
# Out:
# 167

# %%
x = range(len(test_rear))
y1 = test_rear[::-1]
y2 = -1*test_rear[::-1]

# %%
plt.close()
plt.style.use('dark_background')
fig, ax1 = plt.subplots(1, 1, sharex=True)
plt.plot(y1, x)
plt.plot(y2, x)
#ax1.fill_between(x, y2, y1, facecolor='green', interpolate=False)
plt.show()

# %%
plt.close()
plt.plot(y1, x)
plt.plot(y2, x)
#ax1.fill_between(x, y2, y1, facecolor='green', interpolate=False)
plt.savefig('butterfly_' + name_pul[:-3] + '.png', format='png')
